# %%
import sys
import numpy as np
import pandas as pd
from scipy.misc import imread
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from tensorflow.keras.models import Model

from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import MaxPooling2D,Lambda, Flatten, Dense
from keras.layers.merge import Concatenate
from keras.initializers import glorot_uniform

from keras.engine.topology import Layer
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import numpy.random as rng

import tensorflow as tf
from tensorflow.python.tools import freeze_graph
from tensorflow.python.tools import optimize_for_inference_lib

import keras2onnx
import onnx

# %% [markdown]
# ### Please give below paths as per the paths in your system

# %%
train_folder = "../katzen_training/"
val_folder = '../katzen_validierung/'
save_path = '../data/'

# %%
def loadimgs(path,n = 0):
    '''
    path => Path of train directory or test directory
    '''
    X=[]
    y = []
    cat_dict = {}
    lang_dict = {}
    curr_y = n
    # we load every cat folder seperately so we can isolate them later
    for alphabet in os.listdir(path):
        print("loading cat folder: " + alphabet)
        lang_dict[alphabet] = [curr_y,None]
        alphabet_path = os.path.join(path,alphabet)
        # every cat has it's own column in the array, so  load seperately
        for letter in os.listdir(alphabet_path):
            cat_dict[curr_y] = (alphabet, letter)
            category_images=[]
            letter_path = os.path.join(alphabet_path, letter)
            # read all the images in the current category
            for filename in os.listdir(letter_path):
                image_path = os.path.join(letter_path, filename)
                image = imread(image_path, mode='I')
                # image = imread(image_path, mode='L')
                category_images.append(image)
                y.append(curr_y)
            try:
                X.append(np.stack(category_images))
            # edge case  - last one
            except ValueError as e:
                print(e)
                print("error - category_images:", category_images)
            curr_y += 1
            lang_dict[alphabet][1] = curr_y - 1
    y = np.vstack(y)
    X = np.stack(X)
    return X,y,lang_dict

# %% [markdown]
# ### Loading the train images into tensors

# %%
X,y,c=loadimgs(train_folder)
# Out:
# loading cat folder: 01_katzen
# /home/osboxes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %% [markdown]
# ### Saving the train tensors on disk

# %%
with open(os.path.join(save_path,"train.pickle"), "wb") as f:
    pickle.dump((X,c),f)

# %% [markdown]
# ### Loading the validation images into tensors

# %%
Xval,yval,cval=loadimgs(val_folder)
# Out:
# loading cat folder: 02_katzen
# /home/osboxes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %% [markdown]
# ### Saving the validation tensors on disk

# %%
with open(os.path.join(save_path,"val.pickle"), "wb") as f:
    pickle.dump((Xval,cval),f)

# %%
# del X, y ,c ,Xval, yval, cval

# %%
def get_siamese_model(input_shape):
    """
        Model architecture based on the one provided in: http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
    """
    
    # Define the tensors for the two input images
    left_input = Input(input_shape, name="input_1")
    right_input = Input(input_shape, name="input_2")
    
    # Convolutional Neural Network
    model = Sequential()
    #model.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape,
    #               kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(12, (10,10), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D())
    #model.add(Conv2D(128, (7,7), activation='relu',
    #                 kernel_initializer=initialize_weights,
    #                 bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(24, (7,7), activation='relu'))
    model.add(MaxPooling2D())
    #model.add(Conv2D(128, (4,4), activation='relu', kernel_initializer=initialize_weights,
    #                 bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(24, (4,4), activation='relu'))
    model.add(MaxPooling2D())
    #model.add(Conv2D(256, (4,4), activation='relu', kernel_initializer=initialize_weights,
    #                 bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(32, (4,4), activation='relu'))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid'))
    
    # Generate the encodings (feature vectors) for the two images
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    
    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    
    # Add a dense layer with a sigmoid unit to generate the similarity score
    #prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias, name="main_output")(L1_distance)
    prediction = Dense(1,activation='sigmoid', name="main_output")(L1_distance)
    
    # Connect the inputs with the outputs
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    
    # return the model
    return siamese_net

# %%
json_path = '../01_json'

model = get_siamese_model((128, 128, 1))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4096)         8429612     input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4096)         0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            4097        lambda_1[0][0]
# ==================================================================================================
# Total params: 8,433,709
# Trainable params: 8,433,709
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import Image

# %%
optimizer = Adam(lr = 0.00006)
model.compile(loss="binary_crossentropy",optimizer=optimizer)

# %% [markdown]
# ### Loading the train tensors

# %%
with open(os.path.join(save_path, "train.pickle"), "rb") as f:
    (Xtrain, train_classes) = pickle.load(f)
    
print("Training alphabets: \n")
print(list(train_classes.keys()))
# Out:
# Training alphabets:
#
# ['01_katzen']

# %%
with open(os.path.join(save_path, "val.pickle"), "rb") as f:
    (Xval, val_classes) = pickle.load(f)

print("Validation alphabets:", end="\n\n")
print(list(val_classes.keys()))
# Out:
# Validation alphabets:
#
# ['02_katzen']

# %%
def get_batch(batch_size,s="train"):
    """Create batch of n pairs, half same class, half different class"""
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    
    n_classes, n_examples, w, h = X.shape

    # randomly sample several classes to use in the batch
    categories = rng.choice(n_classes,size=(batch_size,),replace=False)
    
    # initialize 2 empty arrays for the input image batch
    pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
    
    # initialize vector for the targets
    targets=np.zeros((batch_size,))
    
    # make one half of it '1's, so 2nd half of batch has same class
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = rng.randint(0, n_examples)
        pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
        idx_2 = rng.randint(0, n_examples)
        
        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category  
        else: 
            # add a random number to the category modulo n classes to ensure 2nd image has a different category
            category_2 = (category + rng.randint(1,n_classes)) % n_classes
        
        pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
    
    return pairs, targets

# %%
def generate(batch_size, s="train"):
    """a generator for batches, so model.fit_generator can be used. """
    while True:
        pairs, targets = get_batch(batch_size,s)
        yield (pairs, targets)

# %%
def make_oneshot_task(N, s="val", language=None):
    """Create pairs of test image, support set for testing N way one-shot learning. """
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape
    
    indices = rng.randint(0, n_examples,size=(N,))
    if language is not None: # if language is specified, select characters for that language
        low, high = categories[language]
        if N > high - low:
            raise ValueError("This language ({}) has less than {} letters".format(language, N))
        categories = rng.choice(range(low,high),size=(N,),replace=False)

    else: # if no language specified just pick a bunch of random letters
        categories = rng.choice(range(n_classes),size=(N,),replace=False)            
    true_category = categories[0]
    ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
    test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
    support_set = X[categories,indices,:,:]
    support_set[0,:,:] = X[true_category,ex2]
    support_set = support_set.reshape(N, w, h,1)
    targets = np.zeros((N,))
    targets[0] = 1
    targets, test_image, support_set = shuffle(targets, test_image, support_set)
    pairs = [test_image,support_set]

    return pairs, targets

# %%
def test_oneshot(model, N, k, s = "val", verbose = 0):
    """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
    n_correct = 0
    if verbose:
        print("Evaluating model on {} random {} way one-shot learning tasks ... \n".format(k,N))
    for i in range(k):
        inputs, targets = make_oneshot_task(N,s)
        probs = model.predict(inputs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct+=1
    percent_correct = (100.0 * n_correct / k)
    if verbose:
        print("Got an average of {}% {} way one-shot learning accuracy \n".format(percent_correct,N))
    return percent_correct

# %%
# Hyper parameters
evaluate_every = 200 # interval for evaluating on one-shot tasks
batch_size = 5
n_iter = 20000 # No. of training iterations
N_way = 2 # how many classes for testing one-shot tasks
n_val = 20 # how many one-shot tasks to validate on
best = -1

# %%
model_path = '../01_weights/'

# %%
print("Starting training process!")
print("-------------------------------------")
t_start = time.time()
for i in range(1, n_iter+1):
    (inputs,targets) = get_batch(batch_size)
    loss = model.train_on_batch(inputs, targets)
    if i % evaluate_every == 0:
        print("\n ------------- \n")
        print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
        print("Train Loss: {0}".format(loss)) 
        val_acc = test_oneshot(model, N_way, n_val, verbose=True)
        model.save_weights(os.path.join(model_path, 'weights.{}.h5'.format(i)))
        if val_acc >= best:
            print("Current best: {0}, previous best: {1}".format(val_acc, best))
            best = val_acc
# Out:
# Starting training process!
# -------------------------------------
# WARNING:tensorflow:From /home/osboxes/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
#  -------------
#
# Time for 50 iterations: 0.6976909319559733 mins
# Train Loss: 0.4293733537197113
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 30.0% 2 way one-shot learning accuracy
#
# Current best: 30.0, previous best: -1
#
#  -------------
#
# Time for 100 iterations: 1.3368849992752074 mins
# Train Loss: 0.7110994458198547
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 55.0% 2 way one-shot learning accuracy
#
# Current best: 55.0, previous best: 30.0
#
#  -------------
#
# Time for 150 iterations: 1.9477234562238057 mins
# Train Loss: 0.7894350290298462
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 80.0% 2 way one-shot learning accuracy
#
# Current best: 80.0, previous best: 55.0
#
#  -------------
#
# Time for 200 iterations: 2.5384541312853495 mins
# Train Loss: 0.5443370938301086
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
# Current best: 90.0, previous best: 80.0
#
#  -------------
#
# Time for 250 iterations: 3.085503335793813 mins
# Train Loss: 0.44417524337768555
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
# Current best: 95.0, previous best: 90.0
#
#  -------------
#
# Time for 300 iterations: 3.6579527219136554 mins
# Train Loss: 0.5331135988235474
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 350 iterations: 4.203890756766001 mins
# Train Loss: 0.20720145106315613
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 85.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 400 iterations: 4.783614722887675 mins
# Train Loss: 0.44838351011276245
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 85.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 450 iterations: 5.340595316886902 mins
# Train Loss: 0.6827189922332764
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 95.0
#
#  -------------
#
# Time for 500 iterations: 5.889861047267914 mins
# Train Loss: 0.2991219460964203
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 550 iterations: 6.43930375178655 mins
# Train Loss: 0.6579903364181519
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 75.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 600 iterations: 6.987032691637675 mins
# Train Loss: 0.2358030378818512
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 650 iterations: 7.536296276251475 mins
# Train Loss: 0.15977928042411804
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 700 iterations: 8.082546055316925 mins
# Train Loss: 0.2879362404346466
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 750 iterations: 8.635306660334269 mins
# Train Loss: 0.3697894513607025
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 800 iterations: 9.183124200503032 mins
# Train Loss: 0.14242136478424072
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Time for 850 iterations: 9.727403064568838 mins
# Train Loss: 0.5088276863098145
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Time for 900 iterations: 10.283642212549845 mins
# Train Loss: 0.20034606754779816
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 85.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 950 iterations: 10.843999544779459 mins
# Train Loss: 0.3489316403865814
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1000 iterations: 11.399402650197347 mins
# Train Loss: 0.3862498998641968
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 85.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1050 iterations: 11.952525707085927 mins
# Train Loss: 0.10551128536462784
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Time for 1100 iterations: 12.513104057312011 mins
# Train Loss: 0.29535961151123047
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1150 iterations: 13.065913351376851 mins
# Train Loss: 0.17573168873786926
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1200 iterations: 13.633858176072438 mins
# Train Loss: 0.5192633271217346
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Time for 1250 iterations: 14.18763445218404 mins
# Train Loss: 0.13250525295734406
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1300 iterations: 14.738897438844045 mins
# Train Loss: 0.23759572207927704
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 85.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1350 iterations: 15.30317036708196 mins
# Train Loss: 0.1196892112493515
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1400 iterations: 15.856058458487192 mins
# Train Loss: 0.22914497554302216
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Time for 1450 iterations: 16.40908365249634 mins
# Train Loss: 0.32687535881996155
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 85.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1500 iterations: 16.961043075720468 mins
# Train Loss: 0.04943670704960823
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1550 iterations: 17.508256129423778 mins
# Train Loss: 0.09561686217784882
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1600 iterations: 18.05846122900645 mins
# Train Loss: 0.06411415338516235
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1650 iterations: 18.61175257364909 mins
# Train Loss: 0.29519712924957275
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1700 iterations: 19.16625431776047 mins
# Train Loss: 0.021906625479459763
# Evaluating model on 20 random 2 way one-shot learning tasks ...
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1750 iterations: 19.718729182084402 mins
# Train Loss: 0.06428368389606476
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 100.0% 2 way one-shot learning accuracy
#
# Current best: 100.0, previous best: 100.0
#
#  -------------
#
# Time for 1800 iterations: 20.303162467479705 mins
# Train Loss: 0.20821042358875275
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 95.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1850 iterations: 20.886699255307516 mins
# Train Loss: 0.338275283575058
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1900 iterations: 21.440525205930076 mins
# Train Loss: 0.1019647940993309
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 85.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 1950 iterations: 21.99329776763916 mins
# Train Loss: 0.14626692235469818
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy
#
#
#  -------------
#
# Time for 2000 iterations: 22.55246827999751 mins
# Train Loss: 0.08210673183202744
# Evaluating model on 20 random 2 way one-shot learning tasks ...
#
# Got an average of 90.0% 2 way one-shot learning accuracy

# %% [markdown]
# ## Some Visualization Functions

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc, h , w, _ = X.shape
    X = X.reshape(nc, h, w)
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img

# %%
def plot_oneshot_task(pairs):
    fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2)
    ax1.matshow(pairs[0][0].reshape(128,128), cmap='CMRmap')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='CMRmap')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
model.load_weights(os.path.join(model_path, "weights.1750.h5"))
pairs, targets = make_oneshot_task(3,"test")
plot_oneshot_task(pairs)
t_start = time.time()
print(model.predict(pairs))
print("Time for prediction %.3fs" % (time.time()-t_start))
print(targets)
# Out:
# [[0.36117497]
#  [0.6610913 ]
#  [0.00143565]]
# Time for prediction 0.134s
# [0. 1. 0.]
